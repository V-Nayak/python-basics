# %% [markdown]
# <a href="https://colab.research.google.com/github/V-Nayak/python-basics/blob/main/venv_juplab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screenshot (16).png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot (15).png](data:image/png;base64,...)
